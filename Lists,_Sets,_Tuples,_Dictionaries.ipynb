# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a0516-prog/NASSCOM/blob/main/Lists%2C_Sets%2C_Tuples%2C_Dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import collections

fruits = ['apple', 'banana', 'cherry', 'apple']
print("original list:", fruits)
print("second fruit:", fruits[1])

# Find duplicates
duplicate_elements = [item for item, count in collections.Counter(fruits).items() if count > 1]
print("Duplicate elements:", duplicate_elements)
# Out:
# original list: ['apple', 'banana', 'cherry', 'apple']
# second fruit: banana
# Duplicate elements: ['apple']

# %%
dimensions = (10, 20, 30)
print("Tuple:", dimensions)
print("second element",dimensions[1])
# Out:
# Tuple: (10, 20, 30)
# second element 20

# %%
unique_numbers = {1, 2, 3, 2, 1}
print("Set (no duplicates):", unique_numbers)
unique_numbers.add(4)
print("after adding 4:",unique_numbers)
unique_numbers.remove(2)
print("After removing 2:", unique_numbers)
# Out:
# Set (no duplicates): {1, 2, 3}
# after adding 4: {1, 2, 3, 4}
# After removing 2: {1, 3, 4}

# %%
student = {
    'name': 'sravs',
    'age': 18,
    'course': 'Python'
}
print("Dictionary:", student)
# Out:
# Dictionary: {'name': 'sravs', 'age': 18, 'course': 'Python'}

# %%
keys = ['id', 'name', 'marks']
values = [101, 'John', 88]
student_info = dict(zip(keys, values))
print("Student Info from zip:", student_info)
# Out:
# Student Info from zip: {'id': 101, 'name': 'John', 'marks': 88}

# %% [markdown]
# # New section

# %% [markdown]
# # New section
