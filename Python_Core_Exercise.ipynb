# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a0516-prog/NASSCOM/blob/main/Python_Core_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}


print("\n--- Task 1: Data Generation and Basic Structures ---")


raw_sensor_data = []

for i in range(100):

    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    device_id = f"DEV{i+1:03}"

    device_type = random.choice(DEVICE_TYPES)

    location = random.choice(LOCATIONS)

    minimum, maximum = READING_RANGES[device_type]
    value = round(random.uniform(minimum, maximum), 2)

    reading = (timestamp, device_id, device_type, location, value)

    raw_sensor_data.append(reading)

for reading in raw_sensor_data[:5]:
    print(reading)


temperature_readings = []

for reading in raw_sensor_data:
    timestamp, device_id, device_type, location, value = reading

    if device_type == "Temperature_Sensor":
        temperature_readings.append({
            "timestamp": timestamp,
            "device_id": device_id,
            "location": location,
            "temperature_celsius": value
        })



print(temperature_readings[:5])

unique_locations = set()

for reading in raw_sensor_data:
    unique_locations.add(reading[3])

print(unique_locations)



device_stats = {}


for device in DEVICE_TYPES:
    device_stats[device] = (float("inf"), float("-inf"))


for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]

    current_min, current_max = device_stats[device_type]

    if value < current_min:
        current_min = value

    if value > current_max:
        current_max = value

    device_stats[device_type] = (current_min, current_max)

print(device_stats)



sliced_readings_1 = raw_sensor_data[9:20]

print(sliced_readings_1)

sliced_readings_2 = raw_sensor_data[::5]

print(sliced_readings_2)

sample_string = "PythonProgrammingIsFun"

substring_1 = sample_string[6:17]

print(substring_1)

substring_2 = sample_string[5::-1]

print(substring_2)



fifth_reading_device_type = raw_sensor_data[4][2]

print(fifth_reading_device_type)

device_type_suffix = fifth_reading_device_type[-6:]

print(device_type_suffix)



def get_readings_by_location(readings_list, target_location):
    result = []

    for reading in readings_list:
        if reading[3] == target_location:
            result.append(reading)

    return result

def generate_report_line(reading_dict):
    return f"[{reading_dict['timestamp']}] Device {reading_dict['device_id']} at {reading_dict['location']}: {reading_dict['temperature_celsius']}°C"

reports_dir = "sensor_reports"

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"Directory '{reports_dir}' created.")
else:
    print(f"Directory '{reports_dir}' already exists.")


first_timestamp = datetime.datetime.strptime(raw_sensor_data[0][0], "%Y-%m-%d %H:%M:%S")
last_timestamp = datetime.datetime.strptime(raw_sensor_data[-1][0], "%Y-%m-%d %H:%M:%S")

duration = last_timestamp - first_timestamp

days = duration.days
hours = duration.seconds // 3600
minutes = (duration.seconds % 3600) // 60

print(f"Duration: {days} days, {hours} hours, {minutes} minutes")


random_values = []

for i in range(5):
    random_values.append(random.randint(100, 200))

print(random_values)
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# --- Task 1: Data Generation and Basic Structures ---
# ('2026-07-19 16:29:23', 'DEV001', 'Temperature_Sensor', 'OfficeB', 21.51)
# ('2026-07-19 16:29:23', 'DEV002', 'Light_Sensor', 'Lab1', 367.46)
# ('2026-07-19 16:29:23', 'DEV003', 'Humidity_Sensor', 'Lab2', 77.68)
# ('2026-07-19 16:29:23', 'DEV004', 'Pressure_Sensor', 'Warehouse', 1002.33)
# ('2026-07-19 16:29:23', 'DEV005', 'Pressure_Sensor', 'Lab2', 980.34)
# [{'timestamp': '2026-07-19 16:29:23', 'device_id': 'DEV001', 'location': 'OfficeB', 'temperature_celsius': 21.51}, {'timestamp': '2026-07-19 16:29:23', 'device_id': 'DEV012', 'location': 'Warehouse', 'temperature_celsius': 28.82}, {'timestamp': '2026-07-19 16:29:23', 'device_id': 'DEV015', 'location': 'OfficeB', 'temperature_celsius': 24.04}, {'timestamp': '2026-07-19 16:29:23', 'device_id': 'DEV021', 'location': 'Lab1', 'temperature_celsius': 18.89}, {'timestamp': '2026-07-19 16:29:23', 'device_id': 'DEV025', 'location': 'Lab2', 'temperature_celsius': 24.81}]
# {'OfficeB', 'Warehouse', 'Lab1', 'Lab2', 'OfficeA'}
# {'Temperature_Sensor': (18.89, 29.49), 'Humidity_Sensor': (30.12, 77.95), 'Pressure_Sensor': (980.34, 1022.48), 'Light_Sensor': (164.72, 992.8)}
# [('2026-07-19 16:29:23', 'DEV010', 'Pressure_Sensor', 'OfficeB', 991.11), ('2026-07-19 16:29:23', 'DEV011', 'Light_Sensor', 'Lab1', 733.0), ('2026-07-19 16:29:23', 'DEV012', 'Temperature_Sensor', 'Warehouse', 28.82), ('2026-07-19 16:29:23', 'DEV013', 'Pressure_Sensor', 'Lab1', 1008.29), ('2026-07-19 16:29:23', 'DEV014', 'Pressure_Sensor', 'OfficeA', 982.3), ('2026-07-19 16:29:23', 'DEV015', 'Temperature_Sensor', 'OfficeB', 24.04), ('2026-07-19 16:29:23', 'DEV016', 'Humidity_Sensor', 'Lab1', 49.39), ('2026-07-19 16:29:23', 'DEV017', 'Pressure_Sensor', 'Lab1', 984.12), ('2026-07-19 16:29:23', 'DEV018', 'Light_Sensor', 'Warehouse', 483.82), ('2026-07-19 16:29:23', 'DEV019', 'Light_Sensor', 'OfficeA', 992.8), ('2026-07-19 16:29:23', 'DEV020', 'Light_Sensor', 'Warehouse', 380.04)]
# [('2026-07-19 16:29:23', 'DEV001', 'Temperature_Sensor', 'OfficeB', 21.51), ('2026-07-19 16:29:23', 'DEV006', 'Humidity_Sensor', 'OfficeA', 66.27), ('2026-07-19 16:29:23', 'DEV011', 'Light_Sensor', 'Lab1', 733.0), ('2026-07-19 16:29:23', 'DEV016', 'Humidity_Sensor', 'Lab1', 49.39), ('2026-07-19 16:29:23', 'DEV021', 'Temperature_Sensor', 'Lab1', 18.89), ('2026-07-19 16:29:23', 'DEV026', 'Light_Sensor', 'OfficeA', 686.02), ('2026-07-19 16:29:23', 'DEV031', 'Pressure_Sensor', 'OfficeA', 1008.16), ('2026-07-19 16:29:23', 'DEV036', 'Temperature_Sensor', 'OfficeB', 27.25), ('2026-07-19 16:29:23', 'DEV041', 'Pressure_Sensor', 'Warehouse', 1019.8), ('2026-07-19 16:29:23', 'DEV046', 'Humidity_Sensor', 'Lab1', 69.27), ('2026-07-19 16:29:23', 'DEV051', 'Light_Sensor', 'OfficeB', 260.5), ('2026-07-19 16:29:23', 'DEV056', 'Temperature_Sensor', 'OfficeB', 29.05), ('2026-07-19 16:29:23', 'DEV061', 'Light_Sensor', 'Warehouse', 460.82), ('2026-07-19 16:29:23', 'DEV066', 'Light_Sensor', 'Warehouse', 217.69), ('2026-07-19 16:29:23', 'DEV071', 'Humidity_Sensor', 'OfficeB', 58.67), ('2026-07-19 16:29:23', 'DEV076', 'Light_Sensor', 'Warehouse', 203.33), ('2026-07-19 16:29:23', 'DEV081', 'Temperature_Sensor', 'Lab1', 27.86), ('2026-07-19 16:29:23', 'DEV086', 'Humidity_Sensor', 'Lab1', 74.13), ('2026-07-19 16:29:23', 'DEV091', 'Humidity_Sensor', 'OfficeB', 46.55), ('2026-07-19 16:29:23', 'DEV096', 'Humidity_Sensor', 'OfficeB', 66.38)]
# Programming
# nohtyP
# Pressure_Sensor
# Sensor
# Directory 'sensor_reports' already exists.
# Duration: 0 days, 0 hours, 0 minutes
# [133, 184, 157, 117, 146]
